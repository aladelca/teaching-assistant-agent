# %% [markdown]
# # Analisis Exploratorio
# Se realiza una descripcion basica del dataset.

# %%
import numpy as np
print("mean:", 10.5)
# Out:
# mean: 10.5

# %% [markdown]
# Conclusiones preliminares.
